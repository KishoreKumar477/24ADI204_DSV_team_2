# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv("/content/Telco-Customer-Churn-.csv")

# %% [markdown]
# ## Exploratory Data Analysis (EDA)
# The "TotalCharges" variable is coerced into a numeric format to resolve implicit string anomalies, preventing runtime exceptions during subsequent mathematical and plotting operations.

# %%
# Convert 'TotalCharges' to numeric, coercing errors to NaN
data['TotalCharges'] = pd.to_numeric(data['TotalCharges'], errors='coerce')

# Drop rows where 'TotalCharges' is NaN (these were likely originally empty strings)
data.dropna(subset=['TotalCharges'], inplace=True)

print("Data after handling TotalCharges missing values:")
display(data.head())
# Out:
# Data after handling TotalCharges missing values:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  4597-NUCQV    Male              1      No         No   -0.34          Yes
# 1  9426-SXNHE  Female              0      No         No   -1.24          Yes
# 2  2379-GYFLQ    Male              0      No         No    0.56          Yes
# 3  3506-LCJDC    Male              0     Yes        Yes   -1.28          Yes
# 4  4374-YMUSQ    Male              0      No         No    0.07          Yes
#
#   MultipleLines InternetService       OnlineSecurity  ...  \
# 0           Yes     Fiber optic                   No  ...
# 1            No     Fiber optic  No internet service  ...
# 2           Yes     Fiber optic                   No  ...
# 3            No              No  No internet service  ...
# 4           Yes     Fiber optic                  Yes  ...
#
#       DeviceProtection          TechSupport          StreamingTV  \
# ...

# %% [markdown]
# ### Univariate Plots

# %%
# 1. Histogram for 'tenure'
plt.figure(figsize=(8, 6))
sns.histplot(data['tenure'], bins=30, kde=True)
plt.title('Distribution of Tenure')
plt.xlabel('Tenure (Months)')
plt.ylabel('Frequency')
plt.show()

# %%
# 2. Boxplot for 'tenure'
plt.figure(figsize=(8, 6))
sns.boxplot(y=data['tenure'])
plt.title('Boxplot of Tenure')
plt.ylabel('Tenure (Months)')
plt.show()

# %%
# 3. Histogram for 'MonthlyCharges'
plt.figure(figsize=(8, 6))
sns.histplot(data['MonthlyCharges'], bins=30, kde=True)
plt.title('Distribution of Monthly Charges')
plt.xlabel('Monthly Charges')
plt.ylabel('Frequency')
plt.show()

# %%
# 4. Boxplot for 'MonthlyCharges'
plt.figure(figsize=(8, 6))
sns.boxplot(y=data['MonthlyCharges'])
plt.title('Boxplot of Monthly Charges')
plt.ylabel('Monthly Charges')
plt.show()

# %%
# 5. Histogram for 'TotalCharges'
plt.figure(figsize=(8, 6))
sns.histplot(data['TotalCharges'], bins=30, kde=True)
plt.title('Distribution of Total Charges')
plt.xlabel('Total Charges')
plt.ylabel('Frequency')
plt.show()

# %%
# 6. Boxplot for 'TotalCharges'
plt.figure(figsize=(8, 6))
sns.boxplot(y=data['TotalCharges'])
plt.title('Boxplot of Total Charges')
plt.ylabel('Total Charges')
plt.show()

# %%
# 7. Bar Chart for 'gender'
plt.figure(figsize=(8, 6))
sns.countplot(x='gender', data=data, palette='viridis')
plt.title('Distribution of Gender')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.show()

# %%
# 8. Bar Chart for 'Partner'
plt.figure(figsize=(8, 6))
sns.countplot(x='Partner', data=data, palette='viridis')
plt.title('Distribution of Partner Status')
plt.xlabel('Partner')
plt.ylabel('Count')
plt.show()

# %%
# 9. Bar Chart for 'Dependents'
plt.figure(figsize=(8, 6))
sns.countplot(x='Dependents', data=data, palette='viridis')
plt.title('Distribution of Dependents Status')
plt.xlabel('Dependents')
plt.ylabel('Count')
plt.show()

# %%
# 10. Bar Chart for 'Churn'
plt.figure(figsize=(8, 6))
sns.countplot(x='Churn', data=data, palette='viridis')
plt.title('Distribution of Churn')
plt.xlabel('Churn')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ### Bivariate Plots

# %%
# 1. Scatter Plot: MonthlyCharges vs Tenure
plt.figure(figsize=(10, 8))
sns.scatterplot(x='tenure', y='MonthlyCharges', hue='Churn', data=data, alpha=0.6)
plt.title('Monthly Charges vs. Tenure (Colored by Churn)')
plt.xlabel('Tenure (Months)')
plt.ylabel('Monthly Charges')
plt.show()

# %%
# 2. Scatter Plot: TotalCharges vs Tenure
plt.figure(figsize=(10, 8))
sns.scatterplot(x='tenure', y='TotalCharges', hue='Churn', data=data, alpha=0.6)
plt.title('Total Charges vs. Tenure (Colored by Churn)')
plt.xlabel('Tenure (Months)')
plt.ylabel('Total Charges')
plt.show()

# %%
# 3. Scatter Plot: MonthlyCharges vs TotalCharges
plt.figure(figsize=(10, 8))
sns.scatterplot(x='MonthlyCharges', y='TotalCharges', hue='Churn', data=data, alpha=0.6)
plt.title('Total Charges vs. Monthly Charges (Colored by Churn)')
plt.xlabel('Monthly Charges')
plt.ylabel('Total Charges')
plt.show()

# %%
# 4. Boxplot: MonthlyCharges by Churn
plt.figure(figsize=(8, 6))
sns.boxplot(x='Churn', y='MonthlyCharges', data=data, palette='coolwarm')
plt.title('Monthly Charges by Churn Status')
plt.xlabel('Churn')
plt.ylabel('Monthly Charges')
plt.show()

# %%
# 5. Boxplot: TotalCharges by Churn
plt.figure(figsize=(8, 6))
sns.boxplot(x='Churn', y='TotalCharges', data=data, palette='coolwarm')
plt.title('Total Charges by Churn Status')
plt.xlabel('Churn')
plt.ylabel('Total Charges')
plt.show()

# %%
# 6. Boxplot: Tenure by Churn
plt.figure(figsize=(8, 6))
sns.boxplot(x='Churn', y='tenure', data=data, palette='coolwarm')
plt.title('Tenure by Churn Status')
plt.xlabel('Churn')
plt.ylabel('Tenure (Months)')
plt.show()

# %%
# 7. Countplot: Gender vs Churn
plt.figure(figsize=(8, 6))
sns.countplot(x='gender', hue='Churn', data=data, palette='pastel')
plt.title('Churn by Gender')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.show()

# %%
# 8. Countplot: InternetService vs Churn
plt.figure(figsize=(10, 7))
sns.countplot(x='InternetService', hue='Churn', data=data, palette='pastel')
plt.title('Churn by Internet Service Type')
plt.xlabel('Internet Service')
plt.ylabel('Count')
plt.show()

# %%
# 9. Countplot: Contract vs Churn
plt.figure(figsize=(10, 7))
sns.countplot(x='Contract', hue='Churn', data=data, palette='pastel')
plt.title('Churn by Contract Type')
plt.xlabel('Contract')
plt.ylabel('Count')
plt.show()

# %%
# 10. Correlation Heatmap for numerical features
numerical_cols = data.select_dtypes(include=np.number).columns
plt.figure(figsize=(10, 8))
sns.heatmap(data[numerical_cols].corr(), annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Heatmap of Numerical Features')
plt.show()
